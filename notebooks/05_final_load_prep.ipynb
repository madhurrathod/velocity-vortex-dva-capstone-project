# %% [markdown]
# # 05 Final Load Prep
#
# Notebook goals:
# - prepare the Tableau-ready file
# - confirm KPI summaries
# - export final analysis tables for dashboard use

# %%
from pathlib import Path
import pandas as pd

BASE_DIR = Path.cwd().resolve().parents[0]
tableau_df = pd.read_csv(BASE_DIR / 'data' / 'processed' / 'bank_marketing_tableau.csv')
tableau_df.head()

# %%
kpi_overview = pd.read_csv(BASE_DIR / 'data' / 'processed' / 'kpi_overview.csv')
kpi_overview

# %%
subscription_by_month = pd.read_csv(BASE_DIR / 'data' / 'processed' / 'subscription_by_month.csv')
subscription_by_month
