# %% [markdown]
# # 01 Extraction
#
# Primary dataset: UCI Bank Marketing (`bank-additional-full.csv`).
#
# Notebook goals:
# - load the raw file
# - inspect shape and columns
# - confirm the target field and basic data quality

# %%
from pathlib import Path
import pandas as pd

BASE_DIR = Path.cwd().resolve().parents[0]
RAW_FILE = BASE_DIR / 'data' / 'raw' / 'bank_marketing' / 'bank-additional' / 'bank-additional' / 'bank-additional-full.csv'
df = pd.read_csv(RAW_FILE, sep=';')
df.shape

# %%
df.head()

# %%
df.info()
